# %%
import os
import io
from zipfile import ZipFile
import pandas as pd
import tensorflow as tf
from PIL import Image
import numpy as np
import random
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import cv2
from sklearn.metrics import *
import os
import zipfile
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2023-01-20 03:33:11.372552: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-20 03:33:11.505733: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-01-20 03:33:12.321875: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2023-01-20 03:33:12.321970: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2023-01-20 03:33:12.321987: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
#백내장 무 폴더 정리
img_dir0 = './eyes_train/eye_train/0'
img0 = os.listdir(img_dir0)
image0 = list(filter(lambda x: x.find('.jpg') != -1 or x.find('.png') != -1, img0))
label0 = list(filter(lambda x : x.find('.json')!=-1,img0))
image_0 = []
image_label0 = []
for i in image0:
    img = np.array(Image.open('./eyes_train/eye_train/0/{}'.format(i)))
    im = img[50:350,50:350]
    im0 = cv2.resize(im,(224,224))
    image_0.append(im0)
    image_label0.append(0)

# %%
#백내장 초기 폴더 정리
img_dir1 = './eyes_train/eye_train/1'
img1 = os.listdir(img_dir1)
image1 = list(filter(lambda x: x.find('.jpg') != -1 or x.find('.png') != -1, img1))
label1 = list(filter(lambda x : x.find('.json')!=-1,img1))
for i in image1:
    img = np.array(Image.open('./eyes_train/eye_train/1/{}'.format(i)))
    im = img[50:350,50:350]
    im1 = cv2.resize(im,(224,224))
    image_0.append(im1)
    image_label0.append(1)

# %%
#백내장 비성숙 폴더 정리
img_dir2 = './eyes_train/eye_train/2'
img2 = os.listdir(img_dir2)
image2 = list(filter(lambda x: x.find('.jpg') != -1 or x.find('.png') != -1, img2))
label2 = list(filter(lambda x : x.find('.json')!=-1,img2))
for i in image2:
    img = np.array(Image.open('./eyes_train/eye_train/2/{}'.format(i)))
    im = img[50:350,50:350]
    im2 = cv2.resize(im,(224,224))
    image_0.append(im2)
    image_label0.append(2)

# %%
#백내장 성숙 폴더 정리
img_dir3 = './eyes_train/eye_train/3'
img3 = os.listdir(img_dir3)
image3 = list(filter(lambda x: x.find('.jpg') != -1 or x.find('.png') != -1, img3))
label3 = list(filter(lambda x : x.find('.json')!=-1,img3))
for i in image3:
    img = np.array(Image.open('./eyes_train/eye_train/3/{}'.format(i)))
    im = img[50:350,50:350]
    im3 = cv2.resize(im,(224,224))
    image_0.append(im3)
    image_label0.append(3)

# %%
x = np.array(image_0)
y = np.array(image_label0)

# %%
#원핫 인코딩
y = np_utils.to_categorical(y)

# %%
#데이터 분할
x_train, x_val, y_train, y_val = train_test_split(x, y, shuffle =True, test_size = 0.2, random_state = 123)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPool2D, Dense, Flatten, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.applications.efficientnet import EfficientNetB4
from tensorflow.nn import silu
#EfficientNetB4불러오기
Eff = EfficientNetB4(weights = 'imagenet', input_shape = (224,224,3), include_top = False, pooling = 'avg')
# Out:
# 2023-01-20 03:34:08.003674: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-20 03:34:08.652920: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38220 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0

# %%
model = Sequential()
#분류기 직접 정리
model.add(Eff)
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('silu'))
model.add(Dense(4,activation = 'softmax'))
model.compile(optimizer=Adam(1e-4), # 옵티마이저 : rmsprop
              loss = 'categorical_crossentropy', # 손실 함수 : sparse_categorical_crossentropy
              metrics = ['accuracy']) # 모니터링 할 평가지표 : 
history = model.fit(x_train, y_train, 
                      epochs = 30, 
                      batch_size = 64, 
                      validation_data = (x_val, y_val))
# Out:
# Epoch 1/30
# 2023-01-20 03:34:46.350617: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/efficientnetb4/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-01-20 03:34:51.559521: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8200
# 2023-01-20 03:34:53.214312: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-01-20 03:34:53.286403: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7ef42a240bf0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-01-20 03:34:53.286437: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# 2023-01-20 03:34:53.292949: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-01-20 03:34:53.441149: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 344/344 [==============================] - 173s 290ms/step - loss: 0.6142 - accuracy: 0.7337 - val_loss: 0.4186 - val_accuracy: 0.8307
# Epoch 2/30
# 344/344 [==============================] - 96s 280ms/step - loss: 0.2930 - accuracy: 0.8875 - val_loss: 0.3164 - val_accuracy: 0.8743
# Epoch 3/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.1295 - accuracy: 0.9534 - val_loss: 0.2875 - val_accuracy: 0.8984
# Epoch 4/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0730 - accuracy: 0.9752 - val_loss: 0.3042 - val_accuracy: 0.9004
# Epoch 5/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0554 - accuracy: 0.9819 - val_loss: 0.2834 - val_accuracy: 0.9081
# Epoch 6/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0408 - accuracy: 0.9860 - val_loss: 0.3216 - val_accuracy: 0.9099
# Epoch 7/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0375 - accuracy: 0.9879 - val_loss: 0.3111 - val_accuracy: 0.9202
# Epoch 8/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0309 - accuracy: 0.9901 - val_loss: 0.2958 - val_accuracy: 0.9168
# Epoch 9/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0289 - accuracy: 0.9903 - val_loss: 0.2962 - val_accuracy: 0.9204
# Epoch 10/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0246 - accuracy: 0.9919 - val_loss: 0.3505 - val_accuracy: 0.9092
# Epoch 11/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0277 - accuracy: 0.9901 - val_loss: 0.3370 - val_accuracy: 0.9115
# Epoch 12/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0260 - accuracy: 0.9914 - val_loss: 0.3300 - val_accuracy: 0.9197
# Epoch 13/30
# 344/344 [==============================] - 96s 278ms/step - loss: 0.0253 - accuracy: 0.9915 - val_loss: 0.3124 - val_accuracy: 0.9193
# Epoch 14/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0223 - accuracy: 0.9926 - val_loss: 0.3421 - val_accuracy: 0.9126
# Epoch 15/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0234 - accuracy: 0.9915 - val_loss: 0.3148 - val_accuracy: 0.9235
# Epoch 16/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0155 - accuracy: 0.9947 - val_loss: 0.3685 - val_accuracy: 0.9095
# Epoch 17/30
# 344/344 [==============================] - 96s 278ms/step - loss: 0.0183 - accuracy: 0.9936 - val_loss: 0.3001 - val_accuracy: 0.9226
# Epoch 18/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0160 - accuracy: 0.9948 - val_loss: 0.3844 - val_accuracy: 0.9095
# Epoch 19/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0147 - accuracy: 0.9951 - val_loss: 0.3255 - val_accuracy: 0.9241
# Epoch 20/30
# 344/344 [==============================] - 96s 278ms/step - loss: 0.0121 - accuracy: 0.9957 - val_loss: 0.3183 - val_accuracy: 0.9248
# Epoch 21/30
# 344/344 [==============================] - 96s 278ms/step - loss: 0.0192 - accuracy: 0.9932 - val_loss: 0.3529 - val_accuracy: 0.9168
# Epoch 22/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0148 - accuracy: 0.9944 - val_loss: 0.3534 - val_accuracy: 0.9233
# Epoch 23/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.3334 - val_accuracy: 0.9271
# Epoch 24/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 0.4033 - val_accuracy: 0.9142
# Epoch 25/30
# 344/344 [==============================] - 96s 278ms/step - loss: 0.0129 - accuracy: 0.9956 - val_loss: 0.3344 - val_accuracy: 0.9255
# Epoch 26/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0130 - accuracy: 0.9955 - val_loss: 0.3206 - val_accuracy: 0.9268
# Epoch 27/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0118 - accuracy: 0.9965 - val_loss: 0.3218 - val_accuracy: 0.9299
# Epoch 28/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.4212 - val_accuracy: 0.9179
# Epoch 29/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.3732 - val_accuracy: 0.9221
# Epoch 30/30
# 344/344 [==============================] - 96s 279ms/step - loss: 0.0117 - accuracy: 0.9963 - val_loss: 0.3412 - val_accuracy: 0.9259

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb4 (Functional)  (None, 1792)             17673823
#
#  dense (Dense)               (None, 512)               918016
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dense_1 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 18,595,939
# Trainable params: 18,469,708
# Non-trainable params: 126,231
# _________________________________________________________________

# %%
# 정확도와 로스 그래프
his_dict = history.history
loss = his_dict['loss']
val_loss = his_dict['val_loss'] 

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize = (10, 5))

# 훈련 및 검증 손실 그리기
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, color = 'blue', label = 'train_loss')
ax1.plot(epochs, val_loss, color = 'orange', label = 'val_loss')
ax1.set_title('train and val loss')
ax1.set_xlabel('epochs')
ax1.set_ylabel('loss')
ax1.legend()

acc = his_dict['accuracy']
val_acc = his_dict['val_accuracy']

# 훈련 및 검증 정확도 그리기
ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, acc, color = 'blue', label = 'train_acc')
ax2.plot(epochs, val_acc, color = 'orange', label = 'val_acc')
ax2.set_title('train and val acc')
ax2.set_xlabel('epochs')
ax2.set_ylabel('acc')
ax2.legend()

plt.show()

# %%
# 6. 모델 저장하기
import h5py
from tensorflow.keras.models import load_model
model.save('./EfficientNetB4_64_tuning01.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_19757/4152185030.py in <module>
#       2 import h5py
#       3 from tensorflow.keras.models import load_model
# ----> 4 model.save('./EfficientNetB4_64_tuning01.h5')
#
# /opt/conda/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /opt/conda/lib/python3.7/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /opt/conda/lib/python3.7/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /opt/conda/lib/python3.7/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# TypeError: Unable to serialize [2.0896919 2.1128857 2.1081853] to JSON. Unrecognized type <class 'tensorflow.python.framework.ops.EagerTensor'>.

# %%
conda list
# Out:
# # packages in environment at /opt/conda:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# absl-py                   1.3.0                    pypi_0    pypi
# aiohttp                   3.8.3                    pypi_0    pypi
# aiohttp-cors              0.7.0                    pypi_0    pypi
# aiorwlock                 1.3.0                    pypi_0    pypi
# aiosignal                 1.3.1                    pypi_0    pypi
# ansiwrap                  0.8.4                    pypi_0    pypi
# anyio                     3.6.2              pyhd8ed1ab_0    conda-forge
# apache-beam               2.43.0                   pypi_0    pypi
# argon2-cffi               21.3.0             pyhd8ed1ab_0    conda-forge
# argon2-cffi-bindings      21.2.0           py37h540881e_2    conda-forge
# astunparse                1.6.3                    pypi_0    pypi
# async-timeout             4.0.2                    pypi_0    pypi
# asynctest                 0.13.0                   pypi_0    pypi
# attrs                     22.1.0             pyh71513ae_1    conda-forge
# babel                     2.11.0                   pypi_0    pypi
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backoff                   1.10.0                   pypi_0    pypi
# backports                 1.0                pyhd8ed1ab_3    conda-forge
# backports.functools_lru_cache 1.6.4              pyhd8ed1ab_0    conda-forge
# beatrix-jupyterlab        2022.128.30523           pypi_0    pypi
# beautifulsoup4            4.11.1             pyha770c72_0    conda-forge
# bleach                    5.0.1              pyhd8ed1ab_0    conda-forge
# blessed                   1.19.1                   pypi_0    pypi
# brotlipy                  0.7.0           py37h27cfd23_1003
# bzip2                     1.0.8                h7f98852_4    conda-forge
# c-ares                    1.18.1               h7f98852_0    conda-forge
# ca-certificates           2022.12.7            ha878542_0    conda-forge
# cachetools                5.2.0                    pypi_0    pypi
# certifi                   2022.12.7          pyhd8ed1ab_0    conda-forge
# cffi                      1.15.1           py37h43b0acd_1    conda-forge
# charset-normalizer        2.1.1              pyhd8ed1ab_0    conda-forge
# click                     8.1.3                    pypi_0    pypi
# cloud-tpu-client          0.10                     pypi_0    pypi
# cloud-tpu-profiler        2.4.0                    pypi_0    pypi
# cloudpickle               2.2.0                    pypi_0    pypi
# cmake                     3.25.0                   pypi_0    pypi
# colorama                  0.4.6                    pypi_0    pypi
# colorful                  0.5.5                    pypi_0    pypi
# commonmark                0.9.1                    pypi_0    pypi
# conda                     22.9.0           py37h89c1867_1    conda-forge
# conda-content-trust       0.1.1              pyhd3eb1b0_0
# conda-package-handling    2.0.2              pyh38be061_0    conda-forge
# conda-package-streaming   0.7.0              pyhd8ed1ab_1    conda-forge
# crcmod                    1.7                      pypi_0    pypi
# cryptography              38.0.2           py37h5994e8b_1    conda-forge
# cudatoolkit               11.2.2              hbe64b41_11    conda-forge
# curl                      7.86.0               hdc1c0ab_2    conda-forge
# cycler                    0.11.0                   pypi_0    pypi
# db-dtypes                 1.0.5                    pypi_0    pypi
# debugpy                   1.6.4                    pypi_0    pypi
# decorator                 5.1.1              pyhd8ed1ab_0    conda-forge
# defusedxml                0.7.1              pyhd8ed1ab_0    conda-forge
# dill                      0.3.1.1                  pypi_0    pypi
# distlib                   0.3.6                    pypi_0    pypi
# dlenv-base                1.0.20221215             py37_0    file:///tmp/conda-pkgs
# dlenv-tf-2-11-gpu         1.0.20221215     py37hbed37c5_0    <unknown>
# dm-tree                   0.1.7                    pypi_0    pypi
# docker                    6.0.1                    pypi_0    pypi
# docopt                    0.6.2                    pypi_0    pypi
# entrypoints               0.4                pyhd8ed1ab_0    conda-forge
# etils                     0.9.0                    pypi_0    pypi
# expat                     2.5.0                h27087fc_0    conda-forge
# explainable-ai-sdk        1.3.3                    pypi_0    pypi
# explainers                0.1                      pypi_0    pypi
# fastapi                   0.88.0                   pypi_0    pypi
# fastavro                  1.7.0                    pypi_0    pypi
# fasteners                 0.18                     pypi_0    pypi
# filelock                  3.8.2                    pypi_0    pypi
# flatbuffers               22.12.6                  pypi_0    pypi
# flit-core                 3.8.0              pyhd8ed1ab_0    conda-forge
# fonttools                 4.38.0                   pypi_0    pypi
# frozenlist                1.3.3                    pypi_0    pypi
# fsspec                    2022.11.0                pypi_0    pypi
# gast                      0.4.0                    pypi_0    pypi
# gcsfs                     2022.11.0                pypi_0    pypi
# gdown                     4.6.0                    pypi_0    pypi
# gettext                   0.21.1               h27087fc_0    conda-forge
# git                       2.39.0          pl5321h693f4a3_0    conda-forge
# gitdb                     4.0.10                   pypi_0    pypi
# gitpython                 3.1.29                   pypi_0    pypi
# google-api-core           1.34.0                   pypi_0    pypi
# google-api-python-client  1.8.0                    pypi_0    pypi
# google-apitools           0.5.31                   pypi_0    pypi
# google-auth               2.15.0                   pypi_0    pypi
# google-auth-httplib2      0.1.0                    pypi_0    pypi
# google-auth-oauthlib      0.8.0                    pypi_0    pypi
# google-cloud-bigquery     3.4.1                    pypi_0    pypi
# google-cloud-bigquery-storage 2.13.2                   pypi_0    pypi
# google-cloud-bigtable     1.7.3                    pypi_0    pypi
# google-cloud-core         2.3.2                    pypi_0    pypi
# google-cloud-datastore    1.15.5                   pypi_0    pypi
# google-cloud-dlp          3.9.2                    pypi_0    pypi
# google-cloud-language     1.3.2                    pypi_0    pypi
# google-cloud-pubsub       2.13.11                  pypi_0    pypi
# google-cloud-pubsublite   1.6.0                    pypi_0    pypi
# google-cloud-recommendations-ai 0.7.1                    pypi_0    pypi
# google-cloud-spanner      3.26.0                   pypi_0    pypi
# google-cloud-storage      2.7.0                    pypi_0    pypi
# google-cloud-videointelligence 1.16.3                   pypi_0    pypi
# google-cloud-vision       1.0.2                    pypi_0    pypi
# google-crc32c             1.5.0                    pypi_0    pypi
# google-pasta              0.2.0                    pypi_0    pypi
# google-resumable-media    2.4.0                    pypi_0    pypi
# googleapis-common-protos  1.57.0                   pypi_0    pypi
# gpustat                   1.0.0                    pypi_0    pypi
# greenlet                  2.0.1                    pypi_0    pypi
# grpc-google-iam-v1        0.12.4                   pypi_0    pypi
# grpcio                    1.51.1                   pypi_0    pypi
# grpcio-status             1.48.2                   pypi_0    pypi
# gviz-api                  1.10.0                   pypi_0    pypi
# gym                       0.23.1                   pypi_0    pypi
# gym-notices               0.0.8                    pypi_0    pypi
# h11                       0.14.0                   pypi_0    pypi
# h5py                      3.7.0                    pypi_0    pypi
# hdfs                      2.7.0                    pypi_0    pypi
# htmlmin                   0.1.12                   pypi_0    pypi
# httplib2                  0.20.4                   pypi_0    pypi
# icu                       70.1                 h27087fc_0    conda-forge
# idna                      3.4                pyhd8ed1ab_0    conda-forge
# imagehash                 4.3.1                    pypi_0    pypi
# imageio                   2.22.4                   pypi_0    pypi
# importlib-metadata        5.1.0                    pypi_0    pypi
# importlib_resources       5.10.1             pyhd8ed1ab_0    conda-forge
# ipykernel                 6.16.2             pyh210e3f2_0    conda-forge
# ipython                   7.34.0                   pypi_0    pypi
# ipython-genutils          0.2.0                    pypi_0    pypi
# ipython-sql               0.4.1                    pypi_0    pypi
# ipython_genutils          0.2.0                      py_1    conda-forge
# ipywidgets                8.0.3                    pypi_0    pypi
# jedi                      0.18.2             pyhd8ed1ab_0    conda-forge
# jinja2                    3.1.2              pyhd8ed1ab_1    conda-forge
# joblib                    1.2.0                    pypi_0    pypi
# json5                     0.9.10                   pypi_0    pypi
# jsonschema                4.17.3             pyhd8ed1ab_0    conda-forge
# jupyter-core              4.12.0                   pypi_0    pypi
# jupyter-http-over-ws      0.0.8                    pypi_0    pypi
# jupyter-server-mathjax    0.2.6                    pypi_0    pypi
# jupyter-server-proxy      3.2.2                    pypi_0    pypi
# jupyter_client            7.4.8              pyhd8ed1ab_0    conda-forge
# jupyter_core              4.11.1           py37h89c1867_0    conda-forge
# jupyter_server            1.23.3             pyhd8ed1ab_0    conda-forge
# jupyterlab                3.4.8                    pypi_0    pypi
# jupyterlab-git            0.41.0                   pypi_0    pypi
# jupyterlab-server         2.16.5                   pypi_0    pypi
# jupyterlab-widgets        3.0.4                    pypi_0    pypi
# jupyterlab_pygments       0.2.2              pyhd8ed1ab_0    conda-forge
# jupytext                  1.14.4                   pypi_0    pypi
# keras                     2.11.0                   pypi_0    pypi
# keras-tuner               1.1.3                    pypi_0    pypi
# keyutils                  1.6.1                h166bdaf_0    conda-forge
# kiwisolver                1.4.4                    pypi_0    pypi
# krb5                      1.20.1               h81ceb04_0    conda-forge
# kt-legacy                 1.0.4                    pypi_0    pypi
# kubernetes                25.3.0                   pypi_0    pypi
# ld_impl_linux-64          2.39                 hcc3a1bd_1    conda-forge
# libclang                  14.0.6                   pypi_0    pypi
# libcurl                   7.86.0               hdc1c0ab_2    conda-forge
# libedit                   3.1.20191231         he28a2e2_2    conda-forge
# libev                     4.33                 h516909a_1    conda-forge
# libffi                    3.4.2                h7f98852_5    conda-forge
# libgcc-ng                 12.2.0              h65d4601_19    conda-forge
# libgomp                   12.2.0              h65d4601_19    conda-forge
# libiconv                  1.17                 h166bdaf_0    conda-forge
# libnghttp2                1.47.0               hff17c54_1    conda-forge
# libnsl                    2.0.0                h7f98852_0    conda-forge
# libsodium                 1.0.18               h36c2ea0_1    conda-forge
# libsqlite                 3.40.0               h753d276_0    conda-forge
# libssh2                   1.10.0               hf14f497_3    conda-forge
# libstdcxx-ng              12.2.0              h46fd767_19    conda-forge
# libuv                     1.44.2               h166bdaf_0    conda-forge
# libzlib                   1.2.13               h166bdaf_4    conda-forge
# llvmlite                  0.39.1                   pypi_0    pypi
# markdown                  3.4.1                    pypi_0    pypi
# markdown-it-py            2.1.0                    pypi_0    pypi
# markupsafe                2.0.1                    pypi_0    pypi
# matplotlib                3.5.3                    pypi_0    pypi
# matplotlib-inline         0.1.6              pyhd8ed1ab_0    conda-forge
# mdit-py-plugins           0.3.3                    pypi_0    pypi
# mdurl                     0.1.2                    pypi_0    pypi
# mistune                   2.0.4              pyhd8ed1ab_0    conda-forge
# msgpack                   1.0.4                    pypi_0    pypi
# multidict                 6.0.3                    pypi_0    pypi
# multimethod               1.9                      pypi_0    pypi
# nb_conda                  2.2.1                    unix_6    conda-forge
# nb_conda_kernels          2.3.1            py37h89c1867_1    conda-forge
# nbclassic                 0.4.8              pyhd8ed1ab_0    conda-forge
# nbclient                  0.7.2                    pypi_0    pypi
# nbconvert                 7.2.6              pyhd8ed1ab_0    conda-forge
# nbconvert-core            7.2.6              pyhd8ed1ab_0    conda-forge
# nbconvert-pandoc          7.2.6              pyhd8ed1ab_0    conda-forge
# nbdime                    3.1.1                    pypi_0    pypi
# nbformat                  5.7.0              pyhd8ed1ab_0    conda-forge
# ncurses                   6.3                  h7f8727e_2
# nest-asyncio              1.5.6              pyhd8ed1ab_0    conda-forge
# networkx                  2.6.3                    pypi_0    pypi
# nodejs                    18.12.1              h8839609_0    conda-forge
# notebook                  6.5.2              pyha770c72_1    conda-forge
# notebook-executor         0.2                      pypi_0    pypi
# notebook-shim             0.2.2              pyhd8ed1ab_0    conda-forge
# numba                     0.56.4                   pypi_0    pypi
# numpy                     1.21.6                   pypi_0    pypi
# nvidia-ml-py              11.495.46                pypi_0    pypi
# oauth2client              4.1.3                    pypi_0    pypi
# oauthlib                  3.2.2                    pypi_0    pypi
# objsize                   0.5.2                    pypi_0    pypi
# opencensus                0.11.0                   pypi_0    pypi
# opencensus-context        0.1.3                    pypi_0    pypi
# opencv-python             4.7.0.68                 pypi_0    pypi
# openssl                   3.0.7                h0b41bf4_1    conda-forge
# opentelemetry-api         1.1.0                    pypi_0    pypi
# opentelemetry-exporter-otlp 1.1.0                    pypi_0    pypi
# opentelemetry-exporter-otlp-proto-grpc 1.1.0                    pypi_0    pypi
# opentelemetry-proto       1.1.0                    pypi_0    pypi
# opentelemetry-sdk         1.1.0                    pypi_0    pypi
# opentelemetry-semantic-conventions 0.20b0                   pypi_0    pypi
# opt-einsum                3.3.0                    pypi_0    pypi
# orjson                    3.8.3                    pypi_0    pypi
# overrides                 6.5.0                    pypi_0    pypi
# packaging                 21.3                     pypi_0    pypi
# pandas                    1.3.5                    pypi_0    pypi
# pandas-profiling          3.5.0                    pypi_0    pypi
# pandoc                    2.19.2               h32600fe_1    conda-forge
# pandocfilters             1.5.0              pyhd8ed1ab_0    conda-forge
# papermill                 2.4.0                    pypi_0    pypi
# parso                     0.8.3              pyhd8ed1ab_0    conda-forge
# patsy                     0.5.3                    pypi_0    pypi
# pcre2                     10.40                hc3806b6_0    conda-forge
# perl                      5.32.1          2_h7f98852_perl5    conda-forge
# pexpect                   4.8.0              pyh1a96a4e_2    conda-forge
# phik                      0.12.3                   pypi_0    pypi
# pickleshare               0.7.5                   py_1003    conda-forge
# pillow                    9.3.0                    pypi_0    pypi
# pip                       22.3.1             pyhd8ed1ab_0    conda-forge
# pkgutil-resolve-name      1.3.10             pyhd8ed1ab_0    conda-forge
# platformdirs              2.6.0                    pypi_0    pypi
# plotly                    5.11.0                   pypi_0    pypi
# prettytable               0.7.2                    pypi_0    pypi
# prometheus-client         0.13.1                   pypi_0    pypi
# prometheus_client         0.15.0             pyhd8ed1ab_0    conda-forge
# promise                   2.3                      pypi_0    pypi
# prompt-toolkit            3.0.36             pyha770c72_0    conda-forge
# proto-plus                1.22.1                   pypi_0    pypi
# protobuf                  3.19.6                   pypi_0    pypi
# psutil                    5.9.3            py37h540881e_0    conda-forge
# ptyprocess                0.7.0              pyhd3deb0d_0    conda-forge
# py-spy                    0.3.14                   pypi_0    pypi
# pyarrow                   7.0.0                    pypi_0    pypi
# pyasn1                    0.4.8                    pypi_0    pypi
# pyasn1-modules            0.2.8                    pypi_0    pypi
# pycosat                   0.6.4            py37h540881e_0    conda-forge
# pycparser                 2.21               pyhd3eb1b0_0
# pydantic                  1.10.2                   pypi_0    pypi
# pydot                     1.4.2                    pypi_0    pypi
# pygments                  2.13.0             pyhd8ed1ab_0    conda-forge
# pyjwt                     2.6.0                    pypi_0    pypi
# pymongo                   3.13.0                   pypi_0    pypi
# pyopenssl                 22.1.0             pyhd8ed1ab_0    conda-forge
# pyparsing                 3.0.9                    pypi_0    pypi
# pyrsistent                0.19.2                   pypi_0    pypi
# pysocks                   1.7.1                    py37_1
# python                    3.7.12          hf930737_100_cpython    conda-forge
# python-dateutil           2.8.2              pyhd8ed1ab_0    conda-forge
# python-fastjsonschema     2.16.2             pyhd8ed1ab_0    conda-forge
# python_abi                3.7                     3_cp37m    conda-forge
# pytz                      2022.6                   pypi_0    pypi
# pywavelets                1.3.0                    pypi_0    pypi
# pyyaml                    6.0                      pypi_0    pypi
# pyzmq                     24.0.1           py37h0c0c2a8_0    conda-forge
# ray                       2.2.0                    pypi_0    pypi
# ray-cpp                   2.2.0                    pypi_0    pypi
# readline                  8.1.2                h7f8727e_1
# regex                     2022.10.31               pypi_0    pypi
# requests                  2.28.1             pyhd8ed1ab_1    conda-forge
# requests-oauthlib         1.3.1                    pypi_0    pypi
# retrying                  1.3.4                    pypi_0    pypi
# rich                      12.6.0                   pypi_0    pypi
# ruamel_yaml               0.15.100         py37h27cfd23_0
# scikit-image              0.19.3                   pypi_0    pypi
# scikit-learn              1.0.2                    pypi_0    pypi
# scipy                     1.7.3                    pypi_0    pypi
# seaborn                   0.12.1                   pypi_0    pypi
# send2trash                1.8.0              pyhd8ed1ab_0    conda-forge
# setuptools                65.5.1             pyhd8ed1ab_0    conda-forge
# simpervisor               0.4                      pypi_0    pypi
# six                       1.16.0             pyhd3eb1b0_1
# smart-open                6.3.0                    pypi_0    pypi
# smmap                     5.0.0                    pypi_0    pypi
# sniffio                   1.3.0              pyhd8ed1ab_0    conda-forge
# soupsieve                 2.3.2.post1        pyhd8ed1ab_0    conda-forge
# sqlalchemy                1.4.45                   pypi_0    pypi
# sqlite                    3.40.0               h4ff8645_0    conda-forge
# sqlparse                  0.4.3                    pypi_0    pypi
# starlette                 0.22.0                   pypi_0    pypi
# statsmodels               0.13.5                   pypi_0    pypi
# tabulate                  0.9.0                    pypi_0    pypi
# tangled-up-in-unicode     0.2.0                    pypi_0    pypi
# tenacity                  8.1.0                    pypi_0    pypi
# tensorboard               2.11.0                   pypi_0    pypi
# tensorboard-data-server   0.6.1                    pypi_0    pypi
# tensorboard-plugin-profile 2.11.1                   pypi_0    pypi
# tensorboard-plugin-wit    1.8.1                    pypi_0    pypi
# tensorboardx              2.5.1                    pypi_0    pypi
# tensorflow                2.11.0                   pypi_0    pypi
# tensorflow-cloud          0.1.16                   pypi_0    pypi
# tensorflow-datasets       4.7.0                    pypi_0    pypi
# tensorflow-estimator      2.11.0                   pypi_0    pypi
# tensorflow-hub            0.12.0                   pypi_0    pypi
# tensorflow-io             0.28.0                   pypi_0    pypi
# tensorflow-io-gcs-filesystem 0.28.0                   pypi_0    pypi
# tensorflow-metadata       1.12.0                   pypi_0    pypi
# tensorflow-probability    0.19.0                   pypi_0    pypi
# tensorflow-serving-api    2.11.0                   pypi_0    pypi
# tensorflow-transform      1.12.0                   pypi_0    pypi
# termcolor                 2.1.1                    pypi_0    pypi
# terminado                 0.17.1             pyh41d4057_0    conda-forge
# textwrap3                 0.9.2                    pypi_0    pypi
# tfx-bsl                   1.12.0                   pypi_0    pypi
# threadpoolctl             3.1.0                    pypi_0    pypi
# tifffile                  2021.11.2                pypi_0    pypi
# tinycss2                  1.2.1              pyhd8ed1ab_0    conda-forge
# tk                        8.6.12               h27826a3_0    conda-forge
# toml                      0.10.2                   pypi_0    pypi
# tomli                     2.0.1                    pypi_0    pypi
# toolz                     0.12.0             pyhd8ed1ab_0    conda-forge
# tornado                   6.2              py37h540881e_0    conda-forge
# tqdm                      4.64.1                   pypi_0    pypi
# traitlets                 5.7.1              pyhd8ed1ab_0    conda-forge
# typeguard                 2.13.3                   pypi_0    pypi
# typer                     0.7.0                    pypi_0    pypi
# typing_extensions         4.4.0              pyha770c72_0    conda-forge
# uritemplate               3.0.1                    pypi_0    pypi
# urllib3                   1.26.13            pyhd8ed1ab_0    conda-forge
# uvicorn                   0.20.0                   pypi_0    pypi
# virtualenv                20.17.1                  pypi_0    pypi
# visions                   0.7.5                    pypi_0    pypi
# wcwidth                   0.2.5              pyh9f0ad1d_2    conda-forge
# webencodings              0.5.1                    pypi_0    pypi
# websocket-client          1.4.2              pyhd8ed1ab_0    conda-forge
# werkzeug                  2.1.2                    pypi_0    pypi
# wheel                     0.38.4             pyhd8ed1ab_0    conda-forge
# widgetsnbextension        4.0.4                    pypi_0    pypi
# witwidget                 1.8.1                    pypi_0    pypi
# wrapt                     1.14.1                   pypi_0    pypi
# xz                        5.2.6                h166bdaf_0    conda-forge
# yaml                      0.2.5                h7b6447c_0
# yarl                      1.8.2                    pypi_0    pypi
# zeromq                    4.3.4                h9c3ff4c_1    conda-forge
# zipp                      3.11.0             pyhd8ed1ab_0    conda-forge
# zlib                      1.2.13               h166bdaf_4    conda-forge
# zstandard                 0.18.0           py37h540881e_0    conda-forge
# Note: you may need to restart the kernel to use updated packages.

# %%
import h5py
print(h5py.__version__)
# Out:
# 3.7.0

# %%
#정확도 f1
from sklearn.metrics import *
def get_clf_eval(y_test,pred): 
  f1 = f1_score(y_test,pred,average="macro") 
  acc = accuracy_score(y_val,predict)   
  loss = model.evaluate(x_val, y_val, batch_size=64)
  print('정확도 :',acc)
  print('f1 score:',f1)
  print('loss :',loss )

# %%
predcit = model.predict(x_val)
predict = []
for i in np.arange(len(predcit)):
  labels = np.argmax(predcit[i])
  predict.append(labels)
predict = np.array(predict)
predict = np_utils.to_categorical(predict)
# Out:
# 172/172 [==============================] - 8s 30ms/step

# %%
#EfficientNetB4
get_clf_eval(y_val,predict)
# Out:
# 86/86 [==============================] - 5s 56ms/step - loss: 0.3412 - accuracy: 0.9259
# 정확도 : 0.9258720930232558
# f1 score: 0.9251708648576592
# loss : [0.34116220474243164, 0.9258720874786377]
